# %% [markdown]
# # Project 3
#
# ## introduction
#
# This notebook contains my model for performing the behavioral cloning necessary to let a simulated car drive down an unkown track.
#
# ## objective
#
# The objective of the assignment is to gain data by driving down "track 1". This data will be used to train a model in such a way that it can clone the behavior and drive down the track itself. In the end the model should be strong enough to drive down an unkown track as well.

# %% [markdown]
# ## to do list
#
# - Obtain "good" training data (DONE)
# - Smooth out steering angles in training data ...
# - Start by creating the network used by the NVIDIA self-driving car (https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) (DONE)
# - normalize data (DONE)
# - Augment data (DONE)
#     - tranform images to create a more balanced set (DONE)
# - Check performance and start tweeking network and hyper parameters (DONE)

# %%
## Import global packages
import numpy as np
import matplotlib.pyplot as plt
import cv2
import csv
import pickle
from tqdm import *
import random
from pathlib import Path
import json
import os
from sklearn.utils import shuffle
import math

# %%
## Global configuration
data_path = './data/6/'
throttle_threshold = 0.02 # Data beneath this threshold will be removed

# %% [markdown]
# ## Load data
#
# I start with loading the data from the CSV file and plotting it to get a sense of the steering angle.

# %%
## Load steering angles and images
csv_path = data_path + 'driving_log.csv'
steering_angles = []
images = []

with open(csv_path) as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        if float(row[4]) > throttle_threshold:
            steering_angles.append(row[3])
            images.append(row[0])
    steering_angles = np.array(steering_angles, dtype=np.float32)

print("No. angles = {}".format(len(steering_angles)))
print("No. images = {}".format(len(images)))
print()
print("ANGLE INFORMATION:")
print("Max angle = {:.3f}".format(np.max(steering_angles)))
print("Min angle = {:.3f}".format(np.min(steering_angles)))
print("Mean angle = {:.3f}".format(np.mean(steering_angles)))
print()
print("DONE: Loading angles and image locations")

## Plot angle line to check smoothness
# %matplotlib inline

figure = plt.figure(figsize=(16,5))
plt.plot(np.arange(len(steering_angles)), steering_angles)
plt.xlabel("Frame")
plt.ylabel("Angle")
# Out:
# No. angles = 5240
# No. images = 5240
#
# ANGLE INFORMATION:
# Max angle = 0.361
# Min angle = -0.506
# Mean angle = -0.037
#
# DONE: Loading angles and image locations

# %%
## Load and normalize the images
def load_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB) 
    return image

def normalize_image(image):
    return image/127.5-1.

# %%
## Check normalization
test_image = load_image(images[300])
test_image_hsv = cv2.cvtColor(test_image, cv2.COLOR_RGB2HSV)
test_image_angle = steering_angles[300]
print(test_image_angle)
print(test_image.shape)
print("Before normalization:")
print("MIN: {:.3f}".format(np.min(test_image_hsv)))
print("MAX: {:.3f}".format(np.max(test_image_hsv)))
print()
normalized_test_image = normalize_image(test_image_hsv)
print("After normalization:")
print("MIN: {:.3f}".format(np.min(normalized_test_image)))
print("MAX: {:.3f}".format(np.max(normalized_test_image)))
# Out:
# -0.0994916
# (160, 320, 3)
# Before normalization:
# MIN: 0.000
# MAX: 255.000
#
# After normalization:
# MIN: -1.000
# MAX: 1.000

# %%
## Plot the normalized test image
figure = plt.figure(figsize=(12,2))
plt.subplot(1,2,1)
plt.title("Loaded image")
plt.imshow(test_image)
plt.subplot(1,2,2)
plt.title("Normalized image")
plt.imshow(normalized_test_image)

# %% [markdown]
# ## Augment data
#
# Augmentation helps with creating more test data. It can also help with training specific things like dealing with shadows etc. I have implemented the following augmentation steps:
#
# 1. Flip images and steering angles to create more images
# 2. Adjust brightness to train the model to deal with different lighting
# 3. Shift images to the left or right and adjust steering angle accordingly

# %%
## Flip image along vertical axis
def flip_image(image, label):
    return np.fliplr(image), -label

# %%
figure = plt.figure(figsize=(8,8))
flipped_x, flipped_y = flip_image(test_image, steering_angles[300])
plt.subplot(1,2,1)
plt.title("Image label = {:.3f}".format(steering_angles[300]))
plt.imshow(test_image)
plt.subplot(1,2,2)
plt.title("Flipped image label = {:.3f}".format(flipped_y))
plt.imshow(flipped_x)

# %%
def adjusted_brightness(image):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
    random_bright = .25+np.random.uniform()
    # slice to select brightness channel only
    image[:,:,2] = image[:,:,2]*random_bright
    return image

# %%
figure = plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.title("Original image")
plt.imshow(test_image)
plt.subplot(1,2,2)
plt.title("Brightness adjusted")
plt.imshow(cv2.cvtColor(adjusted_brightness(cv2.cvtColor(test_image, cv2.COLOR_RGB2BGR)), cv2.COLOR_HSV2RGB))

# %%
## Shift steering angles

def shift_angles(image, steering_angle, trans_range):
    rows, cols, channels = image.shape
    
    ## Horizontal translation
    tr_x = trans_range*np.random.uniform() - trans_range / 2
    steering_angle = steering_angle + tr_x / trans_range * .4
    
    trans_matrix = np.float32([[1,0,tr_x],[0,1,0]])
    trans_image = cv2.warpAffine(image,trans_matrix,(cols,rows))
    return trans_image, steering_angle

# %%
figure = plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.title("Original image angle = {:.3f}".format(steering_angles[300]))
plt.imshow(test_image)
translated_image, translated_steering = shift_angles(test_image, steering_angles[300], 50)
plt.subplot(1,2,2)
plt.title("Translated image angle = {:.3f}".format(translated_steering))
plt.imshow(translated_image)

# %%
def crop_image(image, y1, y2, x1, x2):
    return image[y1:y2, x1:x2]

# %%
figure = plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.title("Original image")
plt.imshow(test_image)
plt.subplot(1,2,2)
plt.title("Cropped image")
cropped = crop_image(test_image, math.floor(test_image.shape[0]/5), test_image.shape[0] - 20, 50, test_image.shape[1] - 50)
plt.imshow(cropped)
print(cropped.shape)
# Out:
# (108, 220, 3)

# %%
## Random choice of camera
left = load_image(images[300].replace('center', 'left'))
left_angle = steering_angles[300] + .25
right = load_image(images[300].replace('center', 'right'))
right_angle = steering_angles[300] - .25
figure = plt.figure(figsize=(12,8))
plt.subplot(1,3,1)
plt.title("Left angle = {:.3f}".format(left_angle))
plt.imshow(left)
plt.subplot(1,3,2)
plt.title("Center angle = {:.3f}".format(steering_angles[300]))
plt.imshow(test_image)
plt.subplot(1,3,3)
plt.title("Right angle = {:.3f}".format(right_angle))
plt.imshow(right)

# %%
## Save training data to file to avoid re-processing images
X_train = images
y_train = steering_angles
training_data = {
    'features': X_train,
    'labels': steering_angles,
}

pickle.dump(training_data, open( "./saved/train.p", "wb" ) )
print("Data saved to train.p file")
# Out:
# Data saved to train.p file

# %%
## Load training data
with open('./saved/train.p', mode='rb') as f:
    train = pickle.load(f)

# %%
## Train set shape
figure = plt.figure(figsize=(2,2))
random_image = random.randint(0, len(X_train))
print("Shape of train set = {}".format(len(X_train)))
print("Shape of labels = {}".format(y_train.shape))
# Out:
# Shape of train set = 5240
# Shape of labels = (5240,)

# %% [markdown]
# ## Generator
#
# Looking at the data we see most of the data has a steering angle of 0 or a super small steering angle. This will make the model bias towards driving straight / small angles. There is also a bias towards a negative steering angle. In order to fix this I am going to work with a generator which will generate the image for each batch on the fly. While it's generating it will have a keep probability which corresponds with the angle size (making it more likely to generate larger angles) and it will augment the data.

# %%
figure = plt.figure(figsize=(12,4))
plt.hist(y_train, 100, normed=1);

# %%
## Batch generate images
def processImage(image, angle, train = True):
    x = cv2.imread(image)
    y = angle
    if train:
        x,y = shift_angles(x, y, 50)
        x = crop_image(x, math.floor(x.shape[0] / 5), x.shape[0] - 20, 50, x.shape[1] - 50)
        if np.random.uniform() > 0.5:
            x,y = flip_image(x,y)
        x = adjusted_brightness(x)
    else:
        x = cv2.cvtColor(x, cv2.COLOR_BGR2HSV)
        x = crop_image(x, math.floor(x.shape[0] / 5), x.shape[0] - 20, 50, x.shape[1] - 50)
    x = cv2.resize(x, (200, 66))
    return x, y
        
def batch_generator_train(data, batch_size = 128):
    data_images, data_angles = data
    while 1:
        images = []
        steering = np.zeros(batch_size)
        for i in range(batch_size):
            random_select = random.randint(0, len(data_images) - 1)
            camera = np.random.choice(['center', 'left', 'right'])
            if camera == 'left':
                image = data_images[random_select].replace('center', 'left')
                angle = data_angles[random_select] + .25
            if camera == 'center':
                image = data_images[random_select]
                angle = data_angles[random_select]
            if camera == 'right':
                image = data_images[random_select].replace('center', 'right')
                angle = data_angles[random_select] - .25
            stop_searching = 0
            while stop_searching == 0:
                x, y = processImage(image, angle, True)
                if abs(y) < .15:
                    stop_searching = 0
                else:
                    stop_searching = 1
            images.append(np.reshape(x, (1,66,200,3)))
            steering[i] = y
        images, steering = (np.vstack(images), steering)
        images, steering = shuffle(images, steering)
        yield images, steering

def batch_generator_validate(data, batch_size = 128):
    data_images, data_angles = data
    while 1: 
        images = []
        steering = np.zeros(batch_size)
        for i in range(batch_size):
            random_select = random.randint(0, len(data_images) - 1)
            x = data_images[random_select]
            y = data_angles[random_select]
            x, y = processImage(x, y, False)
            images.append(np.reshape(x, (1,66,200,3)))
            steering[i] = y
        
        steering = np.array(steering, dtype=np.float32)
        yield np.vstack(images), steering

# %%
batch_train_image, batch_train_angle = next(batch_generator_train((X_train, y_train), 128))
batch_val_image, batch_val_angle = next(batch_generator_validate((X_train, y_train), 128))
print(batch_train_image.shape)
print(batch_train_angle.shape)
# Out:
# (128, 66, 200, 3)
# (128,)

# %%
print(batch_train_image[0].shape)
figure = plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.title("Train image angle = {:.3f}".format(batch_train_angle[0]))
plt.imshow(cv2.cvtColor(batch_train_image[0], cv2.COLOR_HSV2RGB))
plt.subplot(1,2,2)
plt.title("Validation image angle = {:.3f}".format(batch_val_angle[0]))
plt.imshow(cv2.cvtColor(batch_val_image[0], cv2.COLOR_HSV2RGB))
# Out:
# (66, 200, 3)

# %%
figure = plt.figure(figsize=(12,4))
plt.hist(batch_train_angle, 100, normed=1);

# %% [markdown]
# ## The Network
#
# for the network architecture I have looked at NVIDIA's end-to-end network for self driving cars (https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) I have copied the network as described in the blogpost to Keras.

# %%
## Import Keras necessity's
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Lambda
from keras.layers import Input, ELU
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers import Convolution2D, MaxPooling2D, Flatten
from keras.layers.normalization import BatchNormalization
from sklearn.model_selection import train_test_split
from keras.regularizers import l2, activity_l2
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback, TensorBoard

# %%
## Hyper parameters
learning_rate = 0.001
batch_size = 128
epochs = 1
keep_prob = 0.2
regulization_val = 0.01

# %%
## Define model

input_shape = (66, 200, 3) # Define the input shape for the network

model = Sequential()

# Normalization layer, normalize data with GPU power
model.add(Lambda(lambda x: x/127.5 - 1.,input_shape=input_shape, name='normalize1'))

# 1st Convolution 5x5 filter, 2x2 stride
model.add(Convolution2D(3, 5, 5, activation='relu', border_mode='valid', subsample=(2,2), init='he_normal', name='conv1', W_regularizer=l2(regulization_val)))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout1'))

# 2nd Convolution 5x5 filter, 2x2 stride
model.add(Convolution2D(24, 5, 5, activation='relu', border_mode='valid', subsample=(2,2), init='he_normal', name='conv2'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout2'))

# 3rd Convolution 5x5 filter, 2x2 stride
model.add(Convolution2D(36, 5, 5, activation='relu', border_mode='valid', subsample=(2,2), init='he_normal', name='conv3'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout3'))

# 4th Convolution 3x3 filter, 0x0 stride
model.add(Convolution2D(48, 3, 3, activation='relu', border_mode='valid', subsample=(1,1), init='he_normal', name='conv4'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout4'))

# 5th Convolution 3x3 filter, 0x0 stride
model.add(Convolution2D(64, 3, 3, activation='relu', border_mode='valid', subsample=(1,1), init='he_normal', name='conv5'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout5'))

# Flatten layer
model.add(Flatten())

# 1st Fully connected layer, size=100
model.add(Dense(100, init='he_normal', name='hidden1'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout6'))

# 2nd Fully connected layer, size=50
model.add(Dense(50, init='he_normal', name='hidden2'))
model.add(ELU())
model.add(Dropout(keep_prob, name='dropout7'))

# 3rd Fully connected layer, size=10
model.add(Dense(10, init='he_normal', name='hidden3'))
model.add(ELU())

# Output layer
model.add(Dense(1, name='output'))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# normalize1 (Lambda)              (None, 66, 200, 3)    0           lambda_input_3[0][0]
# ____________________________________________________________________________________________________
# conv1 (Convolution2D)            (None, 31, 98, 3)     228         normalize1[0][0]
# ____________________________________________________________________________________________________
# dropout1 (Dropout)               (None, 31, 98, 3)     0           conv1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Convolution2D)            (None, 14, 47, 24)    1824        dropout1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
X_split_train, X_split_val, y_split_train, y_split_val = train_test_split(X_train, y_train, test_size=.2)
train_generator = batch_generator_train((X_split_train, y_split_train), batch_size)
train_validator = batch_generator_validate((X_split_val, y_split_val), batch_size)
print(len(X_split_train))
print(len(X_split_val))
# Out:
# 4192
# 1048

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=2, 
                           verbose=0, mode='min')
tensor_board = TensorBoard(log_dir='./log')

# %%
model.compile(optimizer=Adam(lr=learning_rate), loss='mse')

for i in range(1, 11):
    history = model.fit_generator(
        train_generator,
        samples_per_epoch=128*188,
        nb_epoch=epochs,
        validation_data=train_validator,
        nb_val_samples=128*36,
        callbacks=[early_stop]
    )
    model_file = './results/model-epoch-{}.json'.format(i)
    weights_file = './results/model-epoch-{}.h5'.format(i)
    if Path(model_file).is_file():
        os.remove(model_file)
    json_string = model.to_json()
    with open(model_file,'w' ) as f:
        json.dump(json_string, f)
    if Path(weights_file).is_file():
        os.remove(weights_file)
    model.save_weights(weights_file)
    print("SAVED EPOCH {} TO FILE".format(i))
# Out:
# Epoch 1/1
# 24064/24064 [==============================] - 162s - loss: 0.7291 - val_loss: 0.0591
# SAVED EPOCH 1 TO FILE
# Epoch 1/1
# 24064/24064 [==============================] - 169s - loss: 0.1158 - val_loss: 0.0545
# SAVED EPOCH 2 TO FILE
# Epoch 1/1
# 24064/24064 [==============================] - 166s - loss: 0.0931 - val_loss: 0.0490
# SAVED EPOCH 3 TO FILE
# Epoch 1/1
# 24064/24064 [==============================] - 150s - loss: 0.0842 - val_loss: 0.0456
# SAVED EPOCH 4 TO FILE
# Epoch 1/1
# 19328/24064 [=======================>......] - ETA: 30s - loss: 0.0785
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-037544827878> in <module>()
#       8         validation_data=train_validator,
#       9         nb_val_samples=128*36,
# ---> 10         callbacks=[early_stop]
#      11     )
# ...

# %%
## Saving the model
model_file = './results/model.json'
weights_file = './results/model.h5'
if Path(model_file).is_file():
    os.remove(model_file)
json_string = model.to_json()
with open(model_file,'w' ) as f:
    json.dump(json_string, f)
if Path(weights_file).is_file():
    os.remove(weights_file)
model.save_weights(weights_file)

# %%
test_it = crop_image(test_image_hsv, math.floor(test_image_hsv.shape[0]/5), test_image_hsv.shape[0], 50, test_image_hsv.shape[1] - 50)
test_it = cv2.resize(test_it, (200, 66))
test_it = np.reshape(test_it, (1, 66, 200, 3))
prediction = model.predict(test_it)
print("PREDICTED = {:.3f}".format(prediction[0][0]))
print("ACTUAL = {:.3f}".format(test_image_angle))
# Out:
# PREDICTED = 0.003
# ACTUAL = -0.099

# %% [markdown]
# # Logbook
#
# - 24-01:
#     - I created some initial data, it's far from perfect but it will help me to set up the base of my network.
#     - I created this notebook and started to add code to it.
#     - I loaded the csv file and split the data into steering angles and images (with a throttle threshold)
#     - I plotted the steering angle to get a grasp of the data
#     - I loaded the image files and normalized them
#     - I save the data to a train.p file to avoid lengthy reloading
# - 25-01:
#     - I created a cell to recover the stored training data
#     - I defined the basic NVIDIA model and added dropout layers to prevent overfitting
#     - I created a cell to save the results
# - 29-01:
#     - I confirmed the connection between drive.py and teh simulator
#     - I moved the normalization to the network (to use GPU power)
#     - I started augmenting images by flipping them
# - 30-01:
#     - I created a generator to create images on the fly
#     - Converted the image space to HSV as per description of the NVIDIA paper
#     - Added the warping of image to shift the angle
#     - Added the Udacity provided data set
#     - Still little results on the track ...
# - 31-01:
#     - Removed old code related to the non fit_generator way
#     - Added left and right camera images (with an angle offset)
#     - Added EarlyStop to prevent overfitting
#     - Added extra dropout and L2 regularization
#     - Checked that images where indeed returned in HSV format (the generator did not return correct HSV)
#     - SUCCESSFULLY DRIVEN A LAP ON THE TRAINING TRACK!
# - 01-02 / 06-02:
#     - Did a lot of fiddeling in particular on steering angle augmentation to see if I can get it to work on track 2. So far it's not yet working
# - 07-02:
#     - Start writting up the project and moving the code to a model.js file (instead of notebook) so I can submit it. Will revisit track 2 afterwards.
